# %% [markdown]
# # Point is for user to easily filter by date, overlay sets, choose and customize and graph signals from the backend DB like opensearch

# %% [markdown]
# ### Signal ideas (per set, overlayed)
# - Top 3 or 10 Chase Card, average price index (ungraded)
# - Top 3 or 10 Chase Card, average price index (PSA 10)
# - Top 10 Chase card (ungraded) totalled price
# - Top 10 Chase card (PSA 10) totalled price
# - Top 10 Chase card (ungraded) totalled price : booster box, ratio

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
df = pd.read_csv("price_charting_2024-11-01.csv")

# %%
df.head(3)
# Out:
#    Unnamed: 0   date   price       grade       poke_name poke_no  \
# 0           0  01-21  460.00  bgs_9_half  charizard-vmax      74
# 1           1  02-21  421.18  bgs_9_half  charizard-vmax      74
# 2           2  03-21  436.99  bgs_9_half  charizard-vmax      74
#
#             set_name product_type          execution_datetime
# 0  champion%27s-path         card  2024-10-31 23:18:13.007175
# 1  champion%27s-path         card  2024-10-31 23:18:13.007175
# 2  champion%27s-path         card  2024-10-31 23:18:13.007175

# %%
df.sort_values("date")
# Out:
#         Unnamed: 0   date   price       grade                   poke_name  \
# 0                0  01-21  460.00  bgs_9_half              charizard-vmax
# 94277        94277  01-21    0.00       psa_9                     cynthia
# 94323        94323  01-21    0.00      psa_10                     cynthia
# 94369        94369  01-21    0.00       psa_8                     cynthia
# 94415        94415  01-21   70.00    nearmint                     cynthia
# ...            ...    ...     ...         ...                         ...
# 43527        43527  12-23    5.38    nearmint  single-strike-urshifu-vmax
# 107148      107148  12-23   13.50       psa_8                  ditto-vmax
# 43560        43560  12-23   20.00  bgs_9_half                    arceus-v
# 43458        43458  12-23   11.01       psa_9  single-strike-urshifu-vmax
# 126877      126877  12-23   20.00       psa_9                 silvally-gx
#
#        poke_no           set_name product_type          execution_datetime
# 0           74  champion%27s-path         card  2024-10-31 23:18:13.007175
# 94277     sv82       hidden-fates         card  2024-11-01 01:16:35.246185
# 94323     sv82       hidden-fates         card  2024-11-01 01:16:35.246185
# 94369     sv82       hidden-fates         card  2024-11-01 01:16:35.246185
# 94415     sv82       hidden-fates         card  2024-11-01 01:16:35.246185
# ...        ...                ...          ...                         ...
# 43527     tg19    brilliant-stars         card  2024-11-01 00:14:54.934914
# 107148   sv119      shining-fates         card  2024-11-01 01:29:40.137188
# 43560      165    brilliant-stars         card  2024-11-01 00:15:29.133296
# 43458     tg19    brilliant-stars         card  2024-11-01 00:14:54.934914
# 126877     262     cosmic-eclipse         card  2024-11-01 01:48:26.406551
#
# [172252 rows x 9 columns]

# %%
def convert_timestamps(data):
    converted = {}
    for key, values in data.items():
        # Create a list of dictionaries with formatted date and price
        converted[key] = [{'date': pd.to_datetime(ts[0], unit='ms').strftime('%b %Y'), 'price': ts[1]} for ts in values]
    return converted

# %%
def map_grade(raw_grade):
    proper_grade = ''
    if raw_grade=='used':
        proper_grade = 'nearmint'
    elif raw_grade=='cib':
        proper_grade = 'psa_7'
    elif raw_grade=='new':
        proper_grade = 'psa_8'
    elif raw_grade=='graded':
        proper_grade = 'psa_9'
    elif raw_grade=='boxonly':
        proper_grade = 'bgs_9_half'
    elif raw_grade=='manualonly':
        proper_grade = 'psa_10'

    return proper_grade

# %%
price_scraper("brilliant-stars", "rayquaza", "218", "card")
# Out:
# price_scraper getting url: https://www.pricecharting.com/game/pokemon-evolving-skies/rayquaza-218
# got soup.head.title: <title>Rayquaza VMAX #218 Prices | Pokemon Evolving Skies | Pokemon Cards
# </title>
# converting to df
# df of shape (234, 8)        date  price       grade poke_name poke_no        set_name product_type  \
# 0  Aug 2021    0.0  bgs_9_half  rayquaza     218  evolving-skies         card
# 1  Sep 2021    0.0  bgs_9_half  rayquaza     218  evolving-skies         card
# 2  Oct 2021  525.0  bgs_9_half  rayquaza     218  evolving-skies         card
# 3  Nov 2021  363.0  bgs_9_half  rayquaza     218  evolving-skies         card
# 4  Dec 2021  430.0  bgs_9_half  rayquaza     218  evolving-skies         card
#
#           execution_datetime
# 0 2024-11-01 21:16:50.671360
# 1 2024-11-01 21:16:50.671360
# 2 2024-11-01 21:16:50.671360
# 3 2024-11-01 21:16:50.671360
# 4 2024-11-01 21:16:50.671360
#          date   price       grade poke_name poke_no        set_name  \
# 0    Aug 2021    0.00  bgs_9_half  rayquaza     218  evolving-skies
# 1    Sep 2021    0.00  bgs_9_half  rayquaza     218  evolving-skies
# 2    Oct 2021  525.00  bgs_9_half  rayquaza     218  evolving-skies
# 3    Nov 2021  363.00  bgs_9_half  rayquaza     218  evolving-skies
# 4    Dec 2021  430.00  bgs_9_half  rayquaza     218  evolving-skies
# ..        ...     ...         ...       ...     ...             ...
# 229  Jun 2024  415.69    nearmint  rayquaza     218  evolving-skies
# 230  Jul 2024  367.50    nearmint  rayquaza     218  evolving-skies
# 231  Aug 2024  325.00    nearmint  rayquaza     218  evolving-skies
# 232  Sep 2024  332.50    nearmint  rayquaza     218  evolving-skies
# 233  Nov 2024  330.00    nearmint  rayquaza     218  evolving-skies
#
#     product_type         execution_datetime
# 0           card 2024-11-01 21:16:50.671360
# 1           card 2024-11-01 21:16:50.671360
# 2           card 2024-11-01 21:16:50.671360
# 3           card 2024-11-01 21:16:50.671360
# 4           card 2024-11-01 21:16:50.671360
# ..           ...                        ...
# 229         card 2024-11-01 21:16:50.671360
# 230         card 2024-11-01 21:16:50.671360
# 231         card 2024-11-01 21:16:50.671360
# 232         card 2024-11-01 21:16:50.671360
# 233         card 2024-11-01 21:16:50.671360
#
# [234 rows x 8 columns]

# %%
def price_scraper(set_name, poke_name, poke_no, prod_type):
    # Initialize the Chrome driver
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
    url = f'https://www.pricecharting.com/game/pokemon-{set_name}/{poke_name}-{poke_no}'
    
    if prod_type=='sealed':
        url = f'https://www.pricecharting.com/game/pokemon-{set_name}/{poke_name}'
        print(f"sealed product has url: {url}")

    try:
        print(f"price_scraper getting url: {url}")
        driver.get(url)
        time.sleep(5)  # Wait for the page to load
        
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'html.parser')
        print("got soup.head.title:", soup.head.title)

        chart_data = driver.execute_script("return VGPC.chart_data;")
        converted_data = convert_timestamps(chart_data)
        
        result = []

        if prod_type=="sealed":
            nm_data = converted_data["used"]
            for entry in nm_data:
                entry['grade']='nearmint'
                entry['poke_name']=poke_name
                entry['poke_no']=poke_no
                entry["set_name"]=set_name
                entry["product_type"]="sealed"
                result.append(entry)

        else:        
            for grade, price_arr in converted_data.items():
                for entry in price_arr:                    
                    fmt_grade = map_grade(grade)
                    entry['grade']=fmt_grade
                    entry['poke_name']=poke_name
                    entry['poke_no']=poke_no
                    entry["set_name"]=set_name
                    entry["product_type"]="card"
                    result.append(entry)
        
        print("converting to df")
        df = pd.DataFrame(result)
        df['execution_datetime'] = pd.Timestamp.now()
        print("df of shape", df.shape, df.head(5))
        return df
    
    except Exception as e:
        # maybe return empty df, does concat later effected by this exceptions? 
        # Handle the exception
        print(f"An error occurred: {e}")

    finally:
        driver.quit()  # Make sure to close the browser

# %%
def top_50_set_scraper(set_name):
    url = f'https://www.pricecharting.com/console/pokemon-{set_name}?sort=highest-price&model-number=&exclude-variants=true&show-images=true&in-collection='

    response = requests.get(url)    # Use Beautiful Soup to parse the page source
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all Pokémon names and numbers
    product_data = []
    for title in soup.find_all('td', class_='title'):
        link = title.find('a')
        if link:
            # Get the product_name name and number from the link text
            product_name = link.text.strip().lower()
            data = {}
            print(f"found product name: {product_name}")

            keywords = [" box", "collection", "blister", "bundle", "build and battle", " tin", "booster pack"]
            # if sealed product
            if any(keyword in product_name for keyword in keywords):                
                data["product_name"]=product_name.replace("#", "")
                data["poke_no"]=""
                data["product_type"]="sealed"
            elif '#' in product_name:
                data["product_name"]=product_name.split('#')[0].rstrip() # i.e. Squirtle #151
                data["poke_no"]=product_name.split('#')[1].strip()
                data["product_type"]="card"
            elif 'energy' in product_name:
                data["product_name"]=product_name
                data["poke_no"]=""
                data["product_type"]="card"
            else:
                data["product_name"]=product_name
                data["poke_no"]=""
                data["product_type"]="other"
            
            data["product_name"]=data["product_name"].replace(" ", "-").rstrip('-')
            product_data.append(data)

    for data in product_data:
        print(data)

    print(f'{set_name}: total products scraped={len(product_data)}')
    return product_data

# %%
set_name = "champion%27s-path"
#set_name = "silver-tempest"

# %%
n = top_50_set_scraper(set_name)
# Out:
# found product name: charizard vmax #74
# found product name: charizard v #79
# found product name: elite trainer box
# found product name: suspicious food tin #80
# found product name: booster pack
# found product name: gardevoir vmax #76
# found product name: drednaw vmax #75
# found product name: piers #78
# found product name: kabu #77
# found product name: venusaur v #1
# found product name: alcremie vmax #23
# found product name: gardevoir vmax #17
# found product name: duraludon v #47
# found product name: lucario v #27
# found product name: alcremie v #22
# found product name: galarian cursola v #71
# found product name: incineroar v #8
# found product name: wailord v #13
# found product name: gardevoir v #70
# found product name: drednaw v #69
# found product name: gardevoir v #16
# found product name: hop #73
# found product name: drednaw v #14
# found product name: grapploct v #72
# found product name: galarian cursola v #21
# found product name: drednaw vmax #15
# found product name: marnie #56
# found product name: grapploct v #32
# found product name: eldegoss v #5
# found product name: lycanroc #30
# found product name: scrafty #42
# found product name: zygarde #28
# found product name: galarian obstagoon #37
# found product name: machoke #25
# found product name: rotom phone #64
# found product name: centiskorch #10
# found product name: malamar #45
# found product name: hatterene #20
# found product name: professor's research #62
# found product name: turffield stadium #68
# found product name: vulpix #6
# found product name: galarian zigzagoon #35
# found product name: suspicious food tin #66
# found product name: machamp #26
# found product name: sharpedo #12
# found product name: weedle #2
# found product name: kakuna #3
# found product name: piers #58
# found product name: hop #53
# found product name: beedrill #4
# {'product_name': 'charizard-vmax', 'poke_no': '74', 'product_type': 'card'}
# {'product_name': 'charizard-v', 'poke_no': '79', 'product_type': 'card'}
# {'product_name': 'elite-trainer-box', 'poke_no': '', 'product_type': 'sealed'}
# {'product_name': 'suspicious-food-tin-80', 'poke_no': '', 'product_type': 'sealed'}
# {'product_name': 'booster-pack', 'poke_no': '', 'product_type': 'sealed'}
# {'product_name': 'gardevoir-vmax', 'poke_no': '76', 'product_type': 'card'}
# {'product_name': 'drednaw-vmax', 'poke_no': '75', 'product_type': 'card'}
# {'product_name': 'piers', 'poke_no': '78', 'product_type': 'card'}
# {'product_name': 'kabu', 'poke_no': '77', 'product_type': 'card'}
# {'product_name': 'venusaur-v', 'poke_no': '1', 'product_type': 'card'}
# {'product_name': 'alcremie-vmax', 'poke_no': '23', 'product_type': 'card'}
# {'product_name': 'gardevoir-vmax', 'poke_no': '17', 'product_type': 'card'}
# {'product_name': 'duraludon-v', 'poke_no': '47', 'product_type': 'card'}
# {'product_name': 'lucario-v', 'poke_no': '27', 'product_type': 'card'}
# {'product_name': 'alcremie-v', 'poke_no': '22', 'product_type': 'card'}
# {'product_name': 'galarian-cursola-v', 'poke_no': '71', 'product_type': 'card'}
# {'product_name': 'incineroar-v', 'poke_no': '8', 'product_type': 'card'}
# {'product_name': 'wailord-v', 'poke_no': '13', 'product_type': 'card'}
# {'product_name': 'gardevoir-v', 'poke_no': '70', 'product_type': 'card'}
# {'product_name': 'drednaw-v', 'poke_no': '69', 'product_type': 'card'}
# {'product_name': 'gardevoir-v', 'poke_no': '16', 'product_type': 'card'}
# {'product_name': 'hop', 'poke_no': '73', 'product_type': 'card'}
# {'product_name': 'drednaw-v', 'poke_no': '14', 'product_type': 'card'}
# {'product_name': 'grapploct-v', 'poke_no': '72', 'product_type': 'card'}
# {'product_name': 'galarian-cursola-v', 'poke_no': '21', 'product_type': 'card'}
# {'product_name': 'drednaw-vmax', 'poke_no': '15', 'product_type': 'card'}
# {'product_name': 'marnie', 'poke_no': '56', 'product_type': 'card'}
# {'product_name': 'grapploct-v', 'poke_no': '32', 'product_type': 'card'}
# {'product_name': 'eldegoss-v', 'poke_no': '5', 'product_type': 'card'}
# {'product_name': 'lycanroc', 'poke_no': '30', 'product_type': 'card'}
# {'product_name': 'scrafty', 'poke_no': '42', 'product_type': 'card'}
# {'product_name': 'zygarde', 'poke_no': '28', 'product_type': 'card'}
# {'product_name': 'galarian-obstagoon', 'poke_no': '37', 'product_type': 'card'}
# {'product_name': 'machoke', 'poke_no': '25', 'product_type': 'card'}
# {'product_name': 'rotom-phone', 'poke_no': '64', 'product_type': 'card'}
# {'product_name': 'centiskorch', 'poke_no': '10', 'product_type': 'card'}
# {'product_name': 'malamar', 'poke_no': '45', 'product_type': 'card'}
# {'product_name': 'hatterene', 'poke_no': '20', 'product_type': 'card'}
# {'product_name': "professor's-research", 'poke_no': '62', 'product_type': 'card'}
# {'product_name': 'turffield-stadium', 'poke_no': '68', 'product_type': 'card'}
# {'product_name': 'vulpix', 'poke_no': '6', 'product_type': 'card'}
# {'product_name': 'galarian-zigzagoon', 'poke_no': '35', 'product_type': 'card'}
# {'product_name': 'suspicious-food-tin-66', 'poke_no': '', 'product_type': 'sealed'}
# {'product_name': 'machamp', 'poke_no': '26', 'product_type': 'card'}
# {'product_name': 'sharpedo', 'poke_no': '12', 'product_type': 'card'}
# {'product_name': 'weedle', 'poke_no': '2', 'product_type': 'card'}
# {'product_name': 'kakuna', 'poke_no': '3', 'product_type': 'card'}
# {'product_name': 'piers', 'poke_no': '58', 'product_type': 'card'}
# {'product_name': 'hop', 'poke_no': '53', 'product_type': 'card'}
# {'product_name': 'beedrill', 'poke_no': '4', 'product_type': 'card'}
# champion%27s-path: total products scraped=50

# %%
dataframes=[]
# scrape each product (Max workers = 5 probably)
count=0
for product in n:
    name = product["product_name"]
    num = product["poke_no"]
    product_type = product["product_type"]
    
    print(f"({count}/{len(n)}) scraping {name} #{num} from set: {set_name}")
    df = price_scraper(set_name, name, num, product_type)
    dataframes.append(df)     
    count+=1
# Out:
# (0/50) scraping charizard-vmax #74 from set: champion%27s-path
# price_scraper getting url: https://www.pricecharting.com/game/pokemon-champion%27s-path/charizard-vmax-74
# got soup.head.title: <title>Charizard VMAX #74 Prices | Pokemon Champion's Path | Pokemon Cards
# </title>
# converting to df
# df of shape (276, 8)        date   price       grade       poke_name poke_no           set_name  \
# 0  Jan 2021  460.00  bgs_9_half  charizard-vmax      74  champion%27s-path
# 1  Feb 2021  421.18  bgs_9_half  charizard-vmax      74  champion%27s-path
# 2  Mar 2021  436.99  bgs_9_half  charizard-vmax      74  champion%27s-path
# 3  Apr 2021  412.50  bgs_9_half  charizard-vmax      74  champion%27s-path
# 4  May 2021  360.50  bgs_9_half  charizard-vmax      74  champion%27s-path
#
#   product_type         execution_datetime
# 0         card 2024-10-31 22:31:41.920777
# 1         card 2024-10-31 22:31:41.920777
# 2         card 2024-10-31 22:31:41.920777
# 3         card 2024-10-31 22:31:41.920777
# 4         card 2024-10-31 22:31:41.920777
# (1/50) scraping charizard-v #79 from set: champion%27s-path
# price_scraper getting url: https://www.pricecharting.com/game/pokemon-champion%27s-path/charizard-v-79
# got soup.head.title: <title>Charizard V #79 Prices | Pokemon Champion's Path | Pokemon Cards
# </title>
# converting to df
# df of shape (276, 8)        date   price       grade    poke_name poke_no           set_name  \
# 0  Jan 2021    0.00  bgs_9_half  charizard-v      79  champion%27s-path
# 1  Feb 2021  484.15  bgs_9_half  charizard-v      79  champion%27s-path
# 2  Mar 2021  497.08  bgs_9_half  charizard-v      79  champion%27s-path
# 3  Apr 2021  435.00  bgs_9_half  charizard-v      79  champion%27s-path
# 4  May 2021  410.14  bgs_9_half  charizard-v      79  champion%27s-path
#
#   product_type         execution_datetime
# 0         card 2024-10-31 22:31:55.950288
# 1         card 2024-10-31 22:31:55.950288
# 2         card 2024-10-31 22:31:55.950288
# 3         card 2024-10-31 22:31:55.950288
# 4         card 2024-10-31 22:31:55.950288
# (2/50) scraping elite-trainer-box # from set: champion%27s-path
# sealed product has url: https://www.pricecharting.com/game/pokemon-champion%27s-path/elite-trainer-box
# price_scraper getting url: https://www.pricecharting.com/game/pokemon-champion%27s-path/elite-trainer-box
# got soup.head.title: <title>Elite Trainer Box Prices | Pokemon Champion's Path | Pokemon Cards
# </title>
# converting to df
# df of shape (31, 8)        date  price     grade          poke_name poke_no           set_name  \
# 0  Apr 2022  56.85  nearmint  elite-trainer-box          champion%27s-path
# 1  May 2022  39.00  nearmint  elite-trainer-box          champion%27s-path
# 2  Jun 2022  39.35  nearmint  elite-trainer-box          champion%27s-path
# 3  Jul 2022  63.43  nearmint  elite-trainer-box          champion%27s-path
# 4  Aug 2022  23.96  nearmint  elite-trainer-box          champion%27s-path
#
#   product_type         execution_datetime
# 0       sealed 2024-10-31 22:32:09.652407
# 1       sealed 2024-10-31 22:32:09.652407
# 2       sealed 2024-10-31 22:32:09.652407
# 3       sealed 2024-10-31 22:32:09.652407
# 4       sealed 2024-10-31 22:32:09.652407
# (3/50) scraping suspicious-food-tin-80 # from set: champion%27s-path
# sealed product has url: https://www.pricecharting.com/game/pokemon-champion%27s-path/suspicious-food-tin-80
# price_scraper getting url: https://www.pricecharting.com/game/pokemon-champion%27s-path/suspicious-food-tin-80
# got soup.head.title: <title>Suspicious Food Tin #80 Prices | Pokemon Champion's Path | Pokemon Cards
# </title>
# converting to df
# df of shape (46, 8)        date  price     grade               poke_name poke_no  \
# 0  Jan 2021   2.22  nearmint  suspicious-food-tin-80
# 1  Feb 2021   2.87  nearmint  suspicious-food-tin-80
# 2  Mar 2021   5.00  nearmint  suspicious-food-tin-80
# 3  Apr 2021   3.05  nearmint  suspicious-food-tin-80
# 4  May 2021   4.00  nearmint  suspicious-food-tin-80
#
#             set_name product_type         execution_datetime
# 0  champion%27s-path       sealed 2024-10-31 22:32:23.636969
# 1  champion%27s-path       sealed 2024-10-31 22:32:23.636969
# 2  champion%27s-path       sealed 2024-10-31 22:32:23.636969
# 3  champion%27s-path       sealed 2024-10-31 22:32:23.636969
# 4  champion%27s-path       sealed 2024-10-31 22:32:23.636969
# (4/50) scraping booster-pack # from set: champion%27s-path
# sealed product has url: https://www.pricecharting.com/game/pokemon-champion%27s-path/booster-pack
# price_scraper getting url: https://www.pricecharting.com/game/pokemon-champion%27s-path/booster-pack
# got soup.head.title: <title>Booster Pack Prices | Pokemon Champion's Path | Pokemon Cards
# </title>
# converting to df
# df of shape (25, 8)        date  price     grade     poke_name poke_no           set_name  \
# 0  Oct 2022  17.95  nearmint  booster-pack          champion%27s-path
# 1  Nov 2022  13.41  nearmint  booster-pack          champion%27s-path
# 2  Dec 2022  11.98  nearmint  booster-pack          champion%27s-path
# 3  Jan 2023  15.26  nearmint  booster-pack          champion%27s-path
# 4  Feb 2023  12.08  nearmint  booster-pack          champion%27s-path
#
#   product_type         execution_datetime
# 0       sealed 2024-10-31 22:32:38.131753
# 1       sealed 2024-10-31 22:32:38.131753
# 2       sealed 2024-10-31 22:32:38.131753
# 3       sealed 2024-10-31 22:32:38.131753
# 4       sealed 2024-10-31 22:32:38.131753
# (5/50) scraping gardevoir-vmax #76 from set: champion%27s-path
# price_scraper getting url: https://www.pricecharting.com/game/pokemon-champion%27s-path/gardevoir-vmax-76
# got soup.head.title: <title>Gardevoir VMAX #76 Prices | Pokemon Champion's Path | Pokemon Cards
# </title>
# converting to df
# df of shape (276, 8)        date  price       grade       poke_name poke_no           set_name  \
# 0  Jan 2021    0.0  bgs_9_half  gardevoir-vmax      76  champion%27s-path
# 1  Feb 2021    0.0  bgs_9_half  gardevoir-vmax      76  champion%27s-path
# 2  Mar 2021    0.0  bgs_9_half  gardevoir-vmax      76  champion%27s-path
# 3  Apr 2021    0.0  bgs_9_half  gardevoir-vmax      76  champion%27s-path
# 4  May 2021    0.0  bgs_9_half  gardevoir-vmax      76  champion%27s-path
#
#   product_type         execution_datetime
# 0         card 2024-10-31 22:32:52.068156
# 1         card 2024-10-31 22:32:52.068156
# 2         card 2024-10-31 22:32:52.068156
# 3         card 2024-10-31 22:32:52.068156
# 4         card 2024-10-31 22:32:52.068156
# (6/50) scraping drednaw-vmax #75 from set: champion%27s-path
# price_scraper getting url: https://www.pricecharting.com/game/pokemon-champion%27s-path/drednaw-vmax-75
# got soup.head.title: <title>Drednaw VMAX #75 Prices | Pokemon Champion's Path | Pokemon Cards
# </title>
# converting to df
# df of shape (276, 8)        date  price       grade     poke_name poke_no           set_name  \
# 0  Jan 2021    0.0  bgs_9_half  drednaw-vmax      75  champion%27s-path
# 1  Feb 2021    0.0  bgs_9_half  drednaw-vmax      75  champion%27s-path
# 2  Mar 2021    0.0  bgs_9_half  drednaw-vmax      75  champion%27s-path
# 3  Apr 2021    0.0  bgs_9_half  drednaw-vmax      75  champion%27s-path
# 4  May 2021    0.0  bgs_9_half  drednaw-vmax      75  champion%27s-path
#
#   product_type         execution_datetime
# 0         card 2024-10-31 22:33:07.269234
# 1         card 2024-10-31 22:33:07.269234
# 2         card 2024-10-31 22:33:07.269234
# 3         card 2024-10-31 22:33:07.269234
# 4         card 2024-10-31 22:33:07.269234
# (7/50) scraping piers #78 from set: champion%27s-path
# price_scraper getting url: https://www.pricecharting.com/game/pokemon-champion%27s-path/piers-78
